# %% [markdown]
# <a href="https://colab.research.google.com/github/kareemrasheed89/RasheedRepository/blob/master/Instagram_scrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Scraping Instagram datasets using ***Instagramy*** Library

# %%
#installing necessary library
# !pip install instagramy --upgrade

# %%
# !apt-get -qq install -y instagramy
# Out:
# E: Unable to locate package instagramy

# %%
from instagramy import InstagramUser

session_id ="3245455524%3A8sQ30XYovplXnA%3A8"
# Connecting the profile 
user = InstagramUser("mrfunny1_", sessionid=session_id, from_cache=True) 

# printing the basic details like 
# followers, following, bio 
user.is_verified
user.biography

# return list of dicts 
user.user_data
# Out:
# {'biography': 'Oga Sabinus (Investor)\nInfluencer / Content Creator / Media Personality',
#  'blocked_by_viewer': False,
#  'business_address_json': None,
#  'business_category_name': 'Creators & Celebrities',
#  'business_contact_method': 'CALL',
#  'business_email': None,
#  'business_phone_number': None,
#  'category_enum': 'COMEDIAN',
#  'category_name': 'Comedian',
#  'connected_fb_page': None,
#  'country_block': False,
#  'edge_felix_video_timeline': {'count': 870,
#   'edges': [{'node': {'__typename': 'GraphVideo',
#      'accessibility_caption': None,
#      'coauthor_producers': [],
#      'comments_disabled': False,
#      'dash_info': {'is_dash_eligible': True,
#       'number_of_qualities': 5,
# ...

# %%
data=user.user_data

# %%
import pandas as pd
from pandas.io.json import json_normalize
import json

with open('json_file.json') as data_file:    
    d= json.load(data)  

df = json_normalize(d, 'biography').assign(**d['status'])
print (df)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-6d0a2bcdc84c> in <module>()
#       3 import json
#       4
# ----> 5 with open('json_file.json') as data_file:
#       6     d= json.load(data)
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'json_file.json'

# %%
import pandas as pd
from instagramy.plugins.analysis import analyze_users_popularity,analyze_user_recent_posts

session_id = "3245455524%3A8sQ30XYovplXnA%3A8"

teams = ["thecuteabiola", "donjazzy",
        "mrfunny1_", "brodashaggi",
        "oluwadolarz", "woliagba_ayoajewole",
        "brainjotter"]
data = analyze_users_popularity(teams, session_id)
pd.DataFrame(data)
# Out:
#              Usernames  Followers  Following  Posts
# 0        thecuteabiola    4776298       3884   2797
# 1             donjazzy   13412740       7485   2382
# 2            mrfunny1_    2014831       5784   1839
# 3          brodashaggi   10400902       4047   3816
# 4          oluwadolarz    3758549       1651   2633
# 5  woliagba_ayoajewole    4533968       1668   7124
# 6          brainjotter    1577297       1118    395

# %%
from instagramy.plugins.analysis import analyze_user_recent_posts
user1="donjazzy"
session_id = "3245455524%3A8sQ30XYovplXnA%3A8"
data2 = analyze_user_recent_posts(user1,session_id)
pd.DataFrame(data2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-3c7f2672a95d> in <module>()
#       2 user1="donjazzy"
#       3 session_id = "3245455524%3A8sQ30XYovplXnA%3A8"
# ----> 4 data2 = analyze_user_recent_posts(user1,session_id)
#       5 pd.DataFrame(data2)
#
# /usr/local/lib/python3.7/dist-packages/instagramy/plugins/analysis.py in analyze_user_recent_posts(username, sessionid)
#      36     comments = []
#      37     for post in posts:
# ---> 38         urls.append(post["post_url"])
#      39         likes.append(post["likes"])
#      40         comments.append(post["comments"])
#
# TypeError: tuple indices must be integers or slices, not str
