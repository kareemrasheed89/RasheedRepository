# %% [markdown]
# <a href="https://colab.research.google.com/github/kareemrasheed89/RasheedRepository/blob/master/Exploring_Tweet_Replies_from_twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import tweepy
import pandas as pd

# %%
#consumer_key=""
#consumer_secret=""
#access_token=""
#access_secret=""

# %%
consumer_key="ifTURZtaKCN2XD7h11VxEwkTx"
consumer_secret="g66bPOgqxzOk5sV2yxjfAvbFh9v1U0j3s27cS1oM9ZJ4NvcBAV"
access_token="2422777100-ypak7wtn5jJmFSEka8qojcHAClmVNK7nrnOq2GL"
access_secret="dXxwJRWP6J7amNsU210aiGxr1M11sDTNLjTj73G6liOPD"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth)

# %%
name='goodknight_ng'
target_tweet_id="1386059849633603586"

replies=[]
for tweet in tweepy.Cursor(api.search,q='to:'+name, result_type='recent', timeout=999999).items(1000):
   if hasattr(tweet, 'in_reply_to_status_id_str'):
       if (tweet.in_reply_to_status_id_str==target_tweet_id):
           replies.append(tweet)
 
# update these for whatever tweet you want to process replies to
tweet_pd = pd.DataFrame(replies)

# %%
replies
# Out:
# [Status(_api=<tweepy.api.API object at 0x7efed2b3fc90>, _json={'created_at': 'Fri Apr 30 15:03:31 +0000 2021', 'id': 1388147006544257024, 'id_str': '1388147006544257024', 'text': '@goodknight_ng L x..', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'goodknight_ng', 'name': 'GoodKnight NG', 'id': 1384187107422326787, 'id_str': '1384187107422326787', 'indices': [0, 14]}], 'urls': []}, 'metadata': {'iso_language_code': 'und', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': 1386059849633603586, 'in_reply_to_status_id_str': '1386059849633603586', 'in_reply_to_user_id': 1384187107422326787, 'in_reply_to_user_id_str': '1384187107422326787', 'in_reply_to_screen_name': 'goodknight_ng', 'user': {'id': 1320055324775227394, 'id_str': '1320055324775227394', 'name': 'Jtymword77', 'screen_name': 'jtymword77', 'location': 'Lagos, Nigeria', 'descript
# ...

# %%
tweet_pd.to_csv("/content/drive/MyDrive/Colab Notebooks/GoodKnight_data.csv")

# %%
tweet_pd
# Out:
#                                                      0
# 0    Status(_api=<tweepy.api.API object at 0x7efed2...
# 1    Status(_api=<tweepy.api.API object at 0x7efed2...
# 2    Status(_api=<tweepy.api.API object at 0x7efed2...
# 3    Status(_api=<tweepy.api.API object at 0x7efed2...
# 4    Status(_api=<tweepy.api.API object at 0x7efed2...
# ..                                                 ...
# 167  Status(_api=<tweepy.api.API object at 0x7efed2...
# 168  Status(_api=<tweepy.api.API object at 0x7efed2...
# 169  Status(_api=<tweepy.api.API object at 0x7efed2...
# 170  Status(_api=<tweepy.api.API object at 0x7efed2...
# 171  Status(_api=<tweepy.api.API object at 0x7efed2...
#
# [172 rows x 1 columns]

# %%
tweet_pd.iloc[0]
# Out:
# 0    Status(_api=<tweepy.api.API object at 0x7efed2...
# Name: 0, dtype: object

# %%
def tweetstoDataFrame(tweets):
 
   DataSet = pd.DataFrame()
 
   DataSet['tweetID'] = [tweet.id for tweet in tweets]
   DataSet['tweetText'] = [tweet.text for tweet in tweets]
   ...
   return DataSet
 
#Pass the tweets list to the above function to create a DataFrame
DataSet = tweetstoDataFrame(replies)

DataSet
# Out:
#                  tweetID                                          tweetText
# 0    1388147006544257024                               @goodknight_ng L x..
# 1    1387434658481201159                                   @goodknight_ng J
# 2    1387160242807574534  @goodknight_ng If na malaria is better, let's ...
# 3    1387114382342172685  @goodknight_ng Go sidon bad pipo. Malaria cann...
# 4    1387055076829810689                                  @goodknight_ng ..
# ..                   ...                                                ...
# 167  1386095501293101065                                  @goodknight_ng 🤦🤦
# 168  1386094997838221316  @goodknight_ng That first guy "Lateef", one of...
# 169  1386094241022099456  @goodknight_ng He is so cool and gentle in his...
# 170  1386094188102569989          @goodknight_ng FIGHT AGAINST MALARIA 👊👊👊👊
# 171  1386093504980475905                                  @goodknight_ng ✔️
#
# [172 rows x 2 columns]

# %%
DataSet.to_csv("/content/drive/MyDrive/Colab Notebooks/GoodKnightDataset.csv")

# %% [markdown]
# #KAREEM RASHEED
# #Chief Data Officer
# [Hazon Holdings](https://hazonholdings.com/)
#
# ![Hazon Tech Image.jfif](data:image/jpeg;base64,...)
